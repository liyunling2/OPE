# %% [markdown]
# ## checking datasets

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

BASE_PATH = "../data/marketing/googleAPI/"
agg_new_users = pd.read_parquet(BASE_PATH + "agg_new_users.parquet")
agg_restaurants = pd.read_parquet(BASE_PATH + "agg_restaurants.parquet")
agg_user_activity = pd.read_parquet(BASE_PATH + "agg_user_activity.parquet")
campaign_impact = pd.read_parquet(BASE_PATH + "campaign_impact.parquet")
campaigns_outreach = pd.read_parquet(BASE_PATH + "campaigns_outreach.parquet")
user_demographics = pd.read_parquet(BASE_PATH + "user_demographics.parquet")
session_source = pd.read_parquet(BASE_PATH + "session_source.parquet")

# %%
dfs = {
    "agg_new_users": agg_new_users,
    "agg_restaurants": agg_restaurants,
    "agg_user_activity": agg_user_activity,
    "campaign_impact": campaign_impact,
    "campaigns_outreach": campaigns_outreach,
    "user_demographics": user_demographics,
    "session_source": session_source
}

for name, df in dfs.items():
    print(f"\n===== {name} =====")
    df.info()
# Out:
# ===== agg_new_users =====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   yearMonth                78 non-null     object
#  1   firstUserSourcePlatform  78 non-null     object
#  2   newUsers                 78 non-null     object
#  3   activeUsers              78 non-null     object
# dtypes: object(4)
# memory usage: 2.6+ KB
#
# ===== agg_restaurants =====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34745 entries, 0 to 34744
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   year      34745 non-null  object
#  1   itemId    34745 non-null  object
#  2   itemName  34745 non-null  object
# dtypes: object(3)
# memory usage: 814.5+ KB
#
# ===== agg_user_activity =====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   yearMonth               26 non-null     object
#  1   activeUsers             26 non-null     object
#  2   engagedSessions         26 non-null     object
#  3   sessionsPerUser         26 non-null     object
#  4   userEngagementDuration  26 non-null     object
#  5   addToCarts              26 non-null     object
#  6   checkouts               26 non-null     object
#  7   ecommercePurchases      26 non-null     object
#  8   totalPurchasers         26 non-null     object
#  9   purchaseRevenue         26 non-null     object
#  10  totalRevenue            26 non-null     object
# dtypes: object(11)
# memory usage: 2.4+ KB
#
# ===== campaign_impact =====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18345 entries, 0 to 18344
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   itemId            18345 non-null  object
#  1   itemName          18345 non-null  object
#  2   itemsViewed       18345 non-null  object
#  3   itemsAddedToCart  18345 non-null  object
#  4   itemsPurchased    18345 non-null  object
#  5   itemRevenue       18345 non-null  object
# dtypes: object(6)
# memory usage: 860.0+ KB
#
# ===== campaigns_outreach =====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111528 entries, 0 to 111527
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   yearMonth     111528 non-null  object
#  1   campaignId    111528 non-null  object
#  2   campaignName  111528 non-null  object
#  3   sessions      111528 non-null  object
# dtypes: object(4)
# memory usage: 3.4+ MB
#
# ===== user_demographics =====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   yearMonth           391 non-null    object
#  1   userAgeBracket      391 non-null    object
#  2   userGender          391 non-null    object
#  3   activeUsers         391 non-null    object
#  4   engagedSessions     391 non-null    object
#  5   ecommercePurchases  391 non-null    object
#  6   engagementRate      391 non-null    object
#  7   purchaseRevenue     391 non-null    object
# dtypes: object(8)
# memory usage: 24.6+ KB
#
# ===== session_source =====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12096 entries, 0 to 12095
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   yearMonth                               12096 non-null  object
#  1   sessionSource                           12096 non-null  object
#  2   sessions                                12096 non-null  int64
#  3   sessionKeyEventRate:add_to_cart         12096 non-null  float64
#  4   sessionKeyEventRate:add_to_wishlist     12096 non-null  int64
#  5   sessionKeyEventRate:begin_checkout      12096 non-null  float64
#  6   sessionKeyEventRate:booking             12096 non-null  float64
#  7   sessionKeyEventRate:ecommerce_purchase  12096 non-null  int64
#  8   sessionKeyEventRate:in_app_purchase     12096 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 850.6+ KB

# %%
for name, df in dfs.items():
    print("\nInfo:")
    df.info()
    print("="* 20)
    print("\nMissing values:")
    print(df.isnull().sum())
    print("="* 40)
# Out:
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   yearMonth                78 non-null     object
#  1   firstUserSourcePlatform  78 non-null     object
#  2   newUsers                 78 non-null     object
#  3   activeUsers              78 non-null     object
# dtypes: object(4)
# memory usage: 2.6+ KB
# ====================
#
# Missing values:
# yearMonth                  0
# firstUserSourcePlatform    0
# newUsers                   0
# activeUsers                0
# dtype: int64
# ========================================
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34745 entries, 0 to 34744
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   year      34745 non-null  object
#  1   itemId    34745 non-null  object
#  2   itemName  34745 non-null  object
# dtypes: object(3)
# memory usage: 814.5+ KB
# ====================
#
# Missing values:
# year        0
# itemId      0
# itemName    0
# dtype: int64
# ========================================
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   yearMonth               26 non-null     object
#  1   activeUsers             26 non-null     object
#  2   engagedSessions         26 non-null     object
#  3   sessionsPerUser         26 non-null     object
#  4   userEngagementDuration  26 non-null     object
#  5   addToCarts              26 non-null     object
#  6   checkouts               26 non-null     object
#  7   ecommercePurchases      26 non-null     object
#  8   totalPurchasers         26 non-null     object
#  9   purchaseRevenue         26 non-null     object
#  10  totalRevenue            26 non-null     object
# dtypes: object(11)
# memory usage: 2.4+ KB
# ====================
#
# Missing values:
# yearMonth                 0
# activeUsers               0
# engagedSessions           0
# sessionsPerUser           0
# userEngagementDuration    0
# addToCarts                0
# checkouts                 0
# ecommercePurchases        0
# totalPurchasers           0
# purchaseRevenue           0
# totalRevenue              0
# dtype: int64
# ========================================
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18345 entries, 0 to 18344
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   itemId            18345 non-null  object
#  1   itemName          18345 non-null  object
#  2   itemsViewed       18345 non-null  object
#  3   itemsAddedToCart  18345 non-null  object
#  4   itemsPurchased    18345 non-null  object
#  5   itemRevenue       18345 non-null  object
# dtypes: object(6)
# memory usage: 860.0+ KB
# ====================
#
# Missing values:
# itemId              0
# itemName            0
# itemsViewed         0
# itemsAddedToCart    0
# itemsPurchased      0
# itemRevenue         0
# dtype: int64
# ========================================
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111528 entries, 0 to 111527
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   yearMonth     111528 non-null  object
#  1   campaignId    111528 non-null  object
#  2   campaignName  111528 non-null  object
#  3   sessions      111528 non-null  object
# dtypes: object(4)
# memory usage: 3.4+ MB
# ====================
#
# Missing values:
# yearMonth       0
# campaignId      0
# campaignName    0
# sessions        0
# dtype: int64
# ========================================
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   yearMonth           391 non-null    object
#  1   userAgeBracket      391 non-null    object
#  2   userGender          391 non-null    object
#  3   activeUsers         391 non-null    object
#  4   engagedSessions     391 non-null    object
#  5   ecommercePurchases  391 non-null    object
#  6   engagementRate      391 non-null    object
#  7   purchaseRevenue     391 non-null    object
# dtypes: object(8)
# memory usage: 24.6+ KB
# ====================
#
# Missing values:
# yearMonth             0
# userAgeBracket        0
# userGender            0
# activeUsers           0
# engagedSessions       0
# ecommercePurchases    0
# engagementRate        0
# purchaseRevenue       0
# dtype: int64
# ========================================
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12096 entries, 0 to 12095
# Data columns (total 9 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   yearMonth                               12096 non-null  object
#  1   sessionSource                           12096 non-null  object
#  2   sessions                                12096 non-null  int64
#  3   sessionKeyEventRate:add_to_cart         12096 non-null  float64
#  4   sessionKeyEventRate:add_to_wishlist     12096 non-null  int64
#  5   sessionKeyEventRate:begin_checkout      12096 non-null  float64
#  6   sessionKeyEventRate:booking             12096 non-null  float64
#  7   sessionKeyEventRate:ecommerce_purchase  12096 non-null  int64
#  8   sessionKeyEventRate:in_app_purchase     12096 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 850.6+ KB
# ====================
#
# Missing values:
# yearMonth                                 0
# sessionSource                             0
# sessions                                  0
# sessionKeyEventRate:add_to_cart           0
# sessionKeyEventRate:add_to_wishlist       0
# sessionKeyEventRate:begin_checkout        0
# sessionKeyEventRate:booking               0
# sessionKeyEventRate:ecommerce_purchase    0
# sessionKeyEventRate:in_app_purchase       0
# dtype: int64
# ========================================
